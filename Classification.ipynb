# %%
import sklearn

# %%
ls
# Out:
# Classification.ipynb           datasets/
# Document Classification.ipynb  test.txt
# Gender Classification.ipynb    words5-knuth.txt

# %%
train_data = sklearn.datasets.load_files('datasets/train/')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-2b2cb49dd3f0> in <module>()
# ----> 1 train_data = sklearn.datasets.load_files('datasets/train/')
#
# AttributeError: 'module' object has no attribute 'datasets'

# %%
train_data.target_names
# Out:
# ['atheism', 'buddhism', 'christianity']

# %%
len(train_data.data)
# Out:
# 17

# %%
len(train_data.filenames)
# Out:
# 17

# %%
print("\n".join(train_data.data[0].split("\n")[:3]))
# Out:
# ﻿The Project Gutenberg EBook of The Necessity of Atheism, by Dr. D.M. Brooks
#
# This eBook is for the use of anyone anywhere at no cost and with

# %%
train_data.target[:23]
# Out:
# array([0, 1, 1, 2, 2, 1, 0, 2, 2, 1, 2, 2, 0, 0, 1, 2, 2])

# %%
for t in train_data.target:
    print(train_data.target_names[t])
# Out:
# atheism
# buddhism
# buddhism
# christianity
# christianity
# buddhism
# atheism
# christianity
# christianity
# buddhism
# christianity
# christianity
# atheism
# atheism
# buddhism
# christianity
# christianity

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vect = CountVectorizer(decode_error='ignore')

# %%
X_train_counts = count_vect.fit_transform(train_data.data)

# %%
print(X_train_counts.shape)
# Out:
# (17, 36589)

# %%
print (count_vect.vocabulary_.get(u'brahmin'))
# Out:
# 6782

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (17, 36589)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tfidf, train_data.target)

# %%
clf = MultinomialNB().fit(X_train_tfidf, train_data.target)

# %%
test_data = ['Unexamined life is not worth living', 'Nietzsche said someting', 'God is love', 'Jesus saved us all', 'There is no self', 'Buddha', 'Buddhism', 'Kant', 'Socrates']
X_new_counts = count_vect.transform(test_data)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)
predicted = clf.predict(X_new_tfidf)

# %%
X_new_counts = count_vect.transform(test_data)

# %%
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

# %%
predicted = clf.predict(X_new_tfidf)

# %%
for doc, category in zip(test_data, predicted):
    print('%r => %s' % (doc, data.target_names[category]))
# Out:
# 'Unexamined life is not worth living' => philosophy
# 'Nietzsche said someting' => philosophy
# 'God is love' => philosophy
# 'Jesus saved us all' => philosophy
# 'There is no self' => philosophy
# 'Buddha' => philosophy
# 'Buddhism' => philosophy
# 'Kant' => philosophy
# 'Socrates' => philosophy

# %%
philosophy_data = sklearn.datasets.load_files('datasets/test/')
philosophy_data.data
# Out:
# ['\xef\xbb\xbfThe Project Gutenberg EBook of Thus Spake Zarathustra, by Friedrich Nietzsche\r\n\r\nThis eBook is for the use of anyone anywhere at no cost and with\r\nalmost no restrictions whatsoever.  You may copy it, give it away or\r\nre-use it under the terms of the Project Gutenberg License included\r\nwith this eBook or online at www.gutenberg.org\r\n\r\n\r\nTitle: Thus Spake Zarathustra\r\n       A Book for All and None\r\n\r\nAuthor: Friedrich Nietzsche\r\n\r\nTranslator: Thomas Common\r\n\r\nPosting Date: November 7, 2008 [EBook #1998]\r\nRelease Date: December, 1999\r\n[This file last updated on August 16, 2010]\r\n\r\nLanguage: English\r\n\r\n\r\n*** START OF THIS PROJECT GUTENBERG EBOOK THUS SPAKE ZARATHUSTRA ***\r\n\r\n\r\n\r\n\r\nProduced by Sue Asscher\r\n\r\n\r\n\r\n\r\n\r\nTHUS SPAKE ZARATHUSTRA\r\n\r\nA BOOK FOR ALL AND NONE\r\n\r\n\r\nBy Friedrich Nietzsche\r\n\r\n\r\nTranslated By Thomas Common\r\n\r\n\r\nPG Editor\'s Note:\r\n\r\nArchaic spelling and punctuation
# ...
